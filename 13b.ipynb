# %% [markdown]
# To estimate the population mean revenue with a 95% confidence interval based on the sample data, we can use the formula for a confidence interval for the mean with a known standard deviation. Since the sample size is relatively large (n = 50), we can use the z-distribution (standard normal distribution) to approximate the confidence interval.
#
# Formula for the Confidence Interval
# The confidence interval is given by:
#
# �
# ˉ
# ±
# �
# ×
# �
# �
# x
# ˉ
#  ±z×
# n
# ​
#
# σ
# ​
#
#
# Where:
#
# �
# ˉ
# x
# ˉ
#   is the sample mean.
# �
# z is the z-score corresponding to the desired confidence level (95% in this case).
# �
# σ is the sample standard deviation.
# �
# n is the sample size.
# Calculating the Confidence Interval
# Given:
#
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = $500
# Standard deviation (
# �
# σ) = $50
# Sample size (n) = 50
# For a 95% confidence interval, the z-score (from z-tables or a calculator) is approximately 1.96.
# The confidence interval is calculated as:
#
# 500
# ±
# 1.96
# ×
# 50
# 50
# 500±1.96×
# 50
# ​
#
# 50
# ​
#
#
# 500
# ±
# 1.96
# ×
# 50
# 7.071
# 500±1.96×
# 7.071
# 50
# ​
#
#
# 500
# ±
# 1.96
# ×
# 7.07
# 500±1.96×7.07
#
# 500
# ±
# 13.86
# 500±13.86
#
# So, the 95% confidence interval for the average daily revenue is:
#
# $486.14 \text{ to } $513.86
#
# This means that we can be 95% confident that the true average daily revenue for the coffee shop falls between $486.14 and $513.86.
