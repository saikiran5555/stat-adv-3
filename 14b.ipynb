# %% [markdown]
# To test the researcher's hypothesis that the new drug will decrease blood pressure by 10 mmHg, we can perform a one-sample t-test. The null hypothesis (
# �
# 0
# H
# 0
# ​
#  ) and the alternative hypothesis (
# �
# �
# H
# A
# ​
#  ) in this case are:
#
# �
# 0
# :
# �
# =
# 10
# H
# 0
# ​
#  :μ=10 mmHg (The drug decreases blood pressure by 10 mmHg)
# �
# �
# :
# �
# ≠
# 10
# H
# A
# ​
#  :μ
# 
# =10 mmHg (The drug does not decrease blood pressure by 10 mmHg)
# Here,
# �
# μ is the population mean decrease in blood pressure.
#
# Given data:
#
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = 8 mmHg
# Sample standard deviation (s) = 3 mmHg
# Sample size (n) = 100
# Significance level (
# �
# α) = 0.05
# We will use the t-statistic, which is calculated as:
#
# �
# =
# �
# ˉ
# −
# �
# 0
# �
# /
# �
# t=
# s/
# n
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
#
# where
# �
# 0
# μ
# 0
# ​
#   is the mean under the null hypothesis,
# �
# ˉ
# x
# ˉ
#   is the sample mean,
# �
# s is the sample standard deviation, and
# �
# n is the sample size.
#
# Calculation:
# Plugging in the values:
#
# �
# =
# 8
# −
# 10
# 3
# /
# 100
# =
# −
# 2
# 0.3
# =
# −
# 2
# 0.3
# =
# −
# 6.67
# t=
# 3/
# 100
# ​
#
# 8−10
# ​
#  =
# 0.3
# −2
# ​
#  =−
# 0.3
# 2
# ​
#  =−6.67
#
# Next, we compare the calculated t-value with the critical t-value from the t-distribution table at
# �
# =
# 0.05
# α=0.05 and 99 degrees of freedom (n - 1 = 100 - 1 = 99). However, given the large sample size, we can approximate this using the standard normal distribution.
#
# Decision:
# If the calculated t-value is greater than the critical value (in absolute terms), we reject the null hypothesis.
# If the calculated t-value is within the critical range, we fail to reject the null hypothesis.
