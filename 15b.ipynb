# %% [markdown]
# To test the hypothesis that the true mean weight of the products is less than 5 pounds, we'll use a one-sample t-test for the mean. The null hypothesis (
# �
# 0
# H
# 0
# ​
#  ) and the alternative hypothesis (
# �
# �
# H
# A
# ​
#  ) are as follows:
#
# �
# 0
# :
# �
# =
# 5
# H
# 0
# ​
#  :μ=5 pounds (the true mean weight is 5 pounds)
# �
# �
# :
# �
# <
# 5
# H
# A
# ​
#  :μ<5 pounds (the true mean weight is less than 5 pounds)
# Here,
# �
# μ represents the population mean weight.
#
# Given data:
#
# Population mean (
# �
# 0
# μ
# 0
# ​
#  ) = 5 pounds
# Population standard deviation (
# �
# σ) = 0.5 pounds
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = 4.8 pounds
# Sample size (n) = 25
# Significance level (
# �
# α) = 0.01
# Since we know the population standard deviation, we can use the z-test for this hypothesis test. The z-statistic is calculated as:
#
# �
# =
# �
# ˉ
# −
# �
# 0
# �
# /
# �
# z=
# σ/
# n
# ​
#
# x
# ˉ
#  −μ
# 0
# ​
#
# ​
#
#
# Calculation:
# Plugging in the values:
#
# �
# =
# 4.8
# −
# 5
# 0.5
# /
# 25
# =
# −
# 0.2
# 0.1
# =
# −
# 2
# z=
# 0.5/
# 25
# ​
#
# 4.8−5
# ​
#  =
# 0.1
# −0.2
# ​
#  =−2
#
# Decision:
# Next, we compare the calculated z-value with the critical z-value from the standard normal distribution at
# �
# =
# 0.01
# α=0.01. For a one-tailed test at 0.01 significance level, the critical value is approximately -2.33 (looking up a z-table or using statistical software).
