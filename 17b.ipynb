# %% [markdown]
# To estimate the population mean with a 99% confidence interval based on the sample data, we can use the formula for a confidence interval for the mean when the population standard deviation is unknown (which is typically the case). Since the sample size is less than 30, we'll use the t-distribution.
#
# Given:
#
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = 4
# Sample standard deviation (s) = 1.5
# Sample size (n) = 50
# Confidence level = 99%
# The confidence interval is given by:
#
# �
# ˉ
# ±
# �
# ×
# �
# �
# x
# ˉ
#  ±t×
# n
# ​
#
# s
# ​
#
# where
# �
# t is the t-score from the t-distribution corresponding to the 99% confidence level and 49 degrees of freedom (n-1), and
# �
# �
# n
# ​
#
# s
# ​
#   is the standard error of the mean.
#
# Steps:
# Find the t-Score: Look up the t-score for a 99% confidence level and 49 degrees of freedom. The confidence level is 99%, so each tail has
# 1
# −
# 0.99
# 2
# =
# 0.005
# 2
# 1−0.99
# ​
#  =0.005 (0.5% in each tail). You can use a t-distribution table or a statistical calculator to find this value.
#
# Calculate the Standard Error: The standard error of the mean (SEM) is calculated as
# �
# �
# n
# ​
#
# s
# ​
#  .
#
# Calculate the Confidence Interval: Apply the formula to find the upper and lower bounds of the confidence interval.
#
# Calculation:
# t-Score: For 49 degrees of freedom, the t-score for a 99% confidence level is approximately 2.68 (this value might slightly vary depending on the table or software used).
#
# Standard Error (SEM):
#
# �
# �
# �
# =
# 1.5
# 50
# ≈
# 0.212
# SEM=
# 50
# ​
#
# 1.5
# ​
#  ≈0.212
# Confidence Interval:
#
# Lower Bound
# =
# �
# ˉ
# −
# �
# ×
# �
# �
# �
# =
# 4
# −
# 2.68
# ×
# 0.212
# ≈
# 3.434
# Lower Bound=
# x
# ˉ
#  −t×SEM=4−2.68×0.212≈3.434
# Upper Bound
# =
# �
# ˉ
# +
# �
# ×
# �
# �
# �
# =
# 4
# +
# 2.68
# ×
# 0.212
# ≈
# 4.566
# Upper Bound=
# x
# ˉ
#  +t×SEM=4+2.68×0.212≈4.566
