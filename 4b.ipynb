# %% [markdown]
# To create a hypothesis regarding whether the average weight of male college students is greater than that of female college students, you need to formulate both a null hypothesis and an alternative hypothesis. These hypotheses are the basis for statistical testing.
#
# Null Hypothesis (H₀): The null hypothesis typically represents a statement of 'no effect' or 'no difference'. In this context, the null hypothesis would state that there is no difference in average weight between male and female college students, or that the average weight of male students is less than or equal to that of female students. Formally, it can be expressed as:
#
# �
# 0
# :
# �
# male
# ≤
# �
# female
# H
# 0
# ​
#  :μ
# male
# ​
#  ≤μ
# female
# ​
#
#
# where
# �
# male
# μ
# male
# ​
#   is the population mean weight of male college students and
# �
# female
# μ
# female
# ​
#   is the population mean weight of female college students.
#
# Alternative Hypothesis (H₁ or Hₐ): The alternative hypothesis is what you want to test for. In this case, it's the hypothesis that the average weight of male college students is greater than that of female college students. It can be expressed as:
#
# �
# �
# :
# �
# male
# >
# �
# female
# H
# a
# ​
#  :μ
# male
# ​
#  >μ
# female
# ​
#
#
# This is a one-tailed test because you are specifically interested in testing for a 'greater than' relationship.
